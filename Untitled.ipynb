# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 10]

# %%
nz = np.load("240_256_dataset_main.npz")

# %%
nz

# %%
a, b, c, d = nz

# %%
a
# Out:
# 'x_train'

# %%
nz[a].shape
# Out:
# (2800, 240, 256)

# %%
plt.imshow(nz[a][20])
plt.axis("off")
plt.tick_params(axis='both', left='off', top='off', right='off', bottom='off', labelleft='off', labeltop='off', labelright='off', labelbottom='off')
# plt.savefig('images/foo.png', dpi=100, bbox_inches='tight', pad_inches=0.0)
plt.show()
